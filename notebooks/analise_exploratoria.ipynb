# %%
import pandas as pd

# %%
base_original = pd.read_csv('../pasta_excel/processed.csv', sep='|')
base_original.describe()
# Out:
#             id_casa        precos      metragems       quartos     banheiros  \
# count  1.483900e+04  1.483900e+04   14839.000000  14836.000000  14839.000000
# mean   2.688824e+09  5.205726e+05     150.576184      2.627460      2.372262
# std    9.197583e+07  4.601219e+05    1335.515909      0.909893      1.466654
# min    7.586049e+07  2.300000e+04      10.000000      1.000000      1.000000
# 25%    2.657237e+09  2.600000e+05      64.000000      2.000000      1.000000
# 50%    2.716522e+09  3.800000e+05     109.000000      3.000000      2.000000
# 75%    2.739721e+09  6.000000e+05     172.000000      3.000000      3.000000
# max    2.750508e+09  6.800000e+06  160000.000000     20.000000     30.000000
#
#            garagens  preco_por_metro
# count  14256.000000     14839.000000
# mean       2.260382      4281.260569
# std       13.792498      2603.070110
# min        1.000000         2.810000
# 25%        1.000000      2692.310000
# 50%        2.000000      3741.180000
# ...

# %%
base_original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14839 entries, 0 to 14838
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id_casa                 14839 non-null  int64
#  1   url                     14839 non-null  object
#  2   precos                  14839 non-null  float64
#  3   enderecos_apartamentos  14839 non-null  object
#  4   metragems               14839 non-null  int64
#  5   quartos                 14836 non-null  float64
#  6   banheiros               14839 non-null  int64
#  7   garagens                14256 non-null  float64
#  8   tipo_imovel             14839 non-null  object
#  9   bairro                  14839 non-null  object
#  10  preco_por_metro         14839 non-null  float64
# dtypes: float64(4), int64(3), object(4)
# memory usage: 1.2+ MB

# %%
sorted(base_original['bairro'].unique())
# Out:
# ['Adelino Simioni',
#  'Adão Do Carmo Leonel',
#  'Alamedas Do Botânico',
#  'Alphaville',
#  'Alto Da Boa Vista',
#  'Alto Do Ipiranga',
#  'Antonio Marincek',
#  'Area Rural De Ribeirao Preto',
#  'Avelino Alves Palma',
#  'Bonfim Paulista',
#  'Bosque Das Juritis',
#  'Boulevard',
#  'Campos Eliseos',
#  'Central Park',
#  'Centro',
#  'Chacaras Pedro Correa De Carvalho',
#  'City Ribeirão',
#  'Condominio Arara Azul',
#  'Condominio Balneario Recreativa',
#  'Condominio Genova',
#  'Condominio Mirante Sul',
#  'Condominio Pitangueiras',
#  'Condominio Portal Dos Ipes',
#  'Condominio Saint Gerard',
#  'Condominio San Marco',
#  'Condominio Uirapuru',
#  'Condominio Vila Florenca',
#  'Condominío Chácara Hípica',
#  'Condomínio Aroeira',
#  'Condomínio Buona Vita',
#  'Condomínio Guaporé',
#  'Condomínio Itamaraty',
#  'Condomínio Villa Victória',
#  'Conjunto Habitacional Jardim Das Palmeiras',
#  'Conjunto Habitacional Jardim Das Palmeiras Ii',
#  'Dom Bernardo Jose Mielle',
# ...

# %%
for dados in base_original.query('bairro == "Emir Garcia"').iterrows():
    print(dados)
# Out:
# (8352, id_casa                                                          2749572274
# url                       https://www.vivareal.com.br/imovel/casa-2-quar...
# precos                                                             195000.0
# enderecos_apartamentos    Rua Raimundo Antônio de Bessa - Emir Garcia, R...
# metragems                                                                78
# quartos                                                                 2.0
# banheiros                                                                 1
# garagens                                                                2.0
# tipo_imovel                                                            casa
# bairro                                                          Emir Garcia
# preco_por_metro                                                      2500.0
# Name: 8352, dtype: object)

# %%
base_original.groupby('bairro')['id_casa'].count().reset_index()
# Out:
#                    bairro  id_casa
# 0         Adelino Simioni       38
# 1    Adão Do Carmo Leonel        5
# 2    Alamedas Do Botânico       10
# 3              Alphaville        1
# 4       Alto Da Boa Vista      281
# ..                    ...      ...
# 250          Vila Tiberio        2
# 251          Vila Tibério      313
# 252         Vila Virginia      245
# 253          Villa Romana        1
# 254          Villas Mabel        3
#
# [255 rows x 2 columns]
